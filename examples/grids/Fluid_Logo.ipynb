# %% [markdown]
# # Fluid Logo
#
# [![Google Collab Book](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tum-pbs/PhiFlow/blob/develop/examples/grids/Fluid_Logo.ipynb)
#
#
# This example shows how to run a simple fluid simulation with inflows and obstacles.

# %%
# %pip install phiflow
from phi.jax.flow import *
# from phi.flow import *  # If JAX is not installed. You can use phi.torch or phi.tf as well.
# Out:
# Collecting phiflow
#   Downloading phiflow-3.3.0.tar.gz (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.7/196.7 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting phiml>=1.10.0 (from phiflow)
#   Downloading phiml-1.13.1.tar.gz (342 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.7/342.7 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from phiflow) (3.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from phiflow) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->phiflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->phiflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->phiflow) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->phiflow) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->phiflow) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->phiflow) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->phiflow) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->phiflow) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.11/dist-packages (from phiml>=1.10.0->phiflow) (1.15.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->phiflow) (1.17.0)
# Building wheels for collected packages: phiflow, phiml
#   Building wheel for phiflow (setup.py) ... done
#   Created wheel for phiflow: filename=phiflow-3.3.0-py3-none-any.whl size=225858 sha256=8213ffedc75064973d69fba05c73296390aaf146326d810b08a1cd2df43fc234
#   Stored in directory: /root/.cache/pip/wheels/ef/6c/89/53a65e76ba7aa9586d344ab545c602a5c0a21aa19234949883
#   Building wheel for phiml (setup.py) ... done
#   Created wheel for phiml: filename=phiml-1.13.1-py3-none-any.whl size=357157 sha256=6df8059ca911b12c13ee13c1abd1484ccece24f923a9072839409f8e50b0e597
#   Stored in directory: /root/.cache/pip/wheels/f0/96/cf/d9b47803cd3c398414ddb629901cc88ed36a7efbeb4fb02ddd
# Successfully built phiflow phiml
# Installing collected packages: phiml, phiflow
# Successfully installed phiflow-3.3.0 phiml-1.13.1

# %% [markdown]
# Let's begin by defining the resolution and size of our domain, as well as the obstacle geometries.
# We build a complex obstacle geometry out of multiple boxes here.

# %%
domain = dict(x=128, y=128, bounds=Box(x=100, y=100))
geometries = [Box(x=(15 + x * 7, 15 + (x + 1) * 7), y=(41, 83)) for x in range(1, 10, 2)] + [Box['x,y', 43:50, 41:48], Box['x,y', 15:43, 83:90], Box['x,y', 50:85, 83:90]]
print(geometries)
domain = dict(geometries, bounds=geometries)
geometry = union(geometries)
# Out:
# [Box(x=(22, 29), y=(41, 83)), Box(x=(36, 43), y=(41, 83)), Box(x=(50, 57), y=(41, 83)), Box(x=(64, 71), y=(41, 83)), Box(x=(78, 85), y=(41, 83)), Box(x=(43, 50), y=(41, 48)), Box(x=(15, 43), y=(83, 90)), Box(x=(50, 85), y=(83, 90))]

# %% [markdown]
# Let's plot the obstacle! For the right plot, we sample the geometry on a grid matching our simulation settings. The simulation will only use the sampled version. If you have thin geometries, make sure that they don't result in holes after resampling!

# %%
plot(geometry, CenteredGrid(geometry, 1, **domain))

# %% [markdown]
# Next, we define three smoke inflows for our simulation and sample them on a grid.

# %%
inflow = CenteredGrid(Box(x=(14, 21), y=(6, 10)), ZERO_GRADIENT, **domain) + \
         CenteredGrid(Box(x=(81, 88), y=(6, 10)), ZERO_GRADIENT, **domain) * 0.9 + \
         CenteredGrid(Box(x=(44, 47), y=(49, 51)), ZERO_GRADIENT, **domain) * 0.4
plot(inflow)
# Out:
# /usr/local/lib/python3.11/dist-packages/phi/vis/_matplotlib/_matplotlib_plots.py:167: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()  # because subplot titles can be added after figure creation

# %% [markdown]
# Finally, we define the simulation.
# We let the smoke apply an upwards `buoyancy_force` on the velocity proportional to its density.
# As we sample the velocity on a staggered grid but the smoke density on a centered grid, we need to resample the force to the staggered grid.
# Passing the obstacle to `make_incompressible` ensures that that no fluid can flow into or out of the defined geometry.

# %%
@jit_compile
def step(smoke, v, pressure, inflow, dt=1.):
    smoke = advect.semi_lagrangian(smoke, v, 1) + inflow
    buoyancy_force = resample(smoke * (0, 0.1), to=v)
    v = advect.semi_lagrangian(v, v, 1) + buoyancy_force
    v, pressure = fluid.make_incompressible(v, geometry, Solve('CG-adaptive', 1e-5, x0=pressure))
    return smoke, v, pressure

v0 = StaggeredGrid(0, boundary=0, **domain)
smoke0 = CenteredGrid(0, boundary=ZERO_GRADIENT, **domain)
smoke_trj, v_trj, pressure_trj = iterate(step, batch(time=200), smoke0, v0, None, inflow=inflow)

# %% [markdown]
# Note that passing `batch(time=200)` to `iterate` stacks the variables along a new dimension called `time`.
# This allows us to easily animate the result.

# %%
plot(smoke_trj.time[::2], animate='time')
# Out:
# <video width="864" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...
